# %% [markdown]
# # Steps
# 1. create a  new conda environment `python_ml`
# 2. intall the following packages
#     1. python
#       1. pandas
#       2. numpy
#       3. matplotlib
#       4. seaborn
#       5. scipy
#       6. sciket-learn
#       7. jupyter
#       8. openpyxl
#       9. plotly
#
# # pip install pandas numpy matplotlib seaborn  scipy sciket-learn jupyter openpyxl plotly

# %%
#!pip install pandas matplotlib seaborn  scipy scikit-learn jupyter openpyxl plotly
