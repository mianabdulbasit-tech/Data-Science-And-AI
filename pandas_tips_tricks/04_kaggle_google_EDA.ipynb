# %% [markdown]
# # Google App Store EDA

# %% [markdown]
# ### `EDA definition:` EDA helps you to decide there,what,how ,and which thingss you must  to in order to be on top

# %% [markdown]
# # Assignment :
# 1. Download the data
# 2. Extract data from zip file
# 3. Read the data into python  pandas
# 4. check the column
# 5. Define each column in MD style

# %%
# import libiraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# data import 
df = pd.read_csv('./data/googleplaystore.csv')

# %%
# comment out these codes if you to do auto eda 

# run automatic eda using ydata_profiling library
'''import ydata_profiling as yd
profile = yd.ProfileReport(df)
profile.to_file(output_file='./outputs/04_ydata_googleplaystore_kaggle.html')'''
# Out:
# 100%|██████████| 14/14 [00:04<00:00,  3.48it/s]4<00:01,  2.94it/s, Describe variable: Unnamed: 13]
# Summarize dataset: 100%|██████████| 28/28 [00:08<00:00,  3.30it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:24<00:00, 24.12s/it]
# Render HTML: 100%|██████████| 1/1 [00:03<00:00,  3.35s/it]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 42.64it/s]

# %%
# check the data 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  int64
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10841 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10839 non-null  object
#  13  Unnamed: 13     0 non-null      float64
# dtypes: float64(2), int64(1), object(11)
# memory usage: 1.2+ MB

# %%
# lets have a look on the data
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver  Unnamed: 13
# 0  4.0.3 and up          NaN
# 1  4.0.3 and up          NaN
# 2  4.0.3 and up          NaN
# 3    4.2 and up          NaN
# 4    4.4 and up          NaN

# %%
# takes sample form big dataset

df.sample(10)
# Out:
#                                                      App             Category  \
# 1798   MMX Hill Dash 2 – Offroad Truck, Car & Bike Ra...                 GAME
# 9330                                         EG Way Life               SOCIAL
# 10273                          Fan App for Portsmouth FC               SPORTS
# 7195                                            CE Smart                TOOLS
# 456                                  All Email Providers        COMMUNICATION
# 3840                                Sygic Car Navigation  MAPS_AND_NAVIGATION
# 5219                                            AI Sight         PRODUCTIVITY
# 6746                                       BS Where Am I                TOOLS
# 10619  Hidden Object Florida Vacation Adventure Fun Game               FAMILY
# 4403    Dark Infusion Substratum Theme for Android N & O      PERSONALIZATION
#
#        Rating  Reviews  Size    Installs  Type  Price Content Rating  \
# 1798      4.4    41975   79M  1,000,000+  Free      0       Everyone
# 9330      NaN        0  1.1M         50+  Free      0       Everyone
# 10273     4.5       53   12M      1,000+  Free      0           Teen
# 7195      5.0        3   29M        100+  Free      0       Everyone
# 456       4.1    20901  7.3M  1,000,000+  Free      0       Everyone
# 3840      4.7   162049   48M  5,000,000+  Free      0       Everyone
# 5219      3.5       43   48M      1,000+  Free      0       Everyone
# 6746      NaN        9  2.8M         50+  Free      0       Everyone
# 10619     3.7      126   45M     10,000+  Free      0       Everyone
# 4403      4.8      133   59M      1,000+  Paid  $2.49       Everyone
#
#                   Genres    Last Updated Current Ver   Android Ver  \
# 1798              Racing   July 19, 2018  3.00.11034    5.0 and up
# 9330              Social  April 27, 2016         1.0    4.1 and up
# 10273             Sports  August 6, 2016      060816    4.2 and up
# 7195               Tools    May 28, 2018       2.2.0    4.1 and up
# 456        Communication   April 3, 2018       5.0.9    4.1 and up
# 3840   Maps & Navigation  August 7, 2018      18.0.2    4.4 and up
# 5219        Productivity   June 18, 2018         1.2  4.0.3 and up
# 6746               Tools    July 5, 2018         2.3    2.3 and up
# 10619             Casual   June 18, 2018         1.4  4.0.3 and up
# 4403     Personalization  August 3, 2018        15.6    7.0 and up
#
#        Unnamed: 13
# 1798           NaN
# 9330           NaN
# 10273          NaN
# 7195           NaN
# 456            NaN
# 3840           NaN
# 5219           NaN
# 6746           NaN
# 10619          NaN
# 4403           NaN

# %%
df.describe()
# Out:
#             Rating       Reviews  Unnamed: 13
# count  9367.000000  1.084100e+04          0.0
# mean      4.191513  4.441119e+05          NaN
# std       0.515735  2.927629e+06          NaN
# min       1.000000  0.000000e+00          NaN
# 25%       4.000000  3.800000e+01          NaN
# 50%       4.300000  2.094000e+03          NaN
# 75%       4.500000  5.476800e+04          NaN
# max       5.000000  7.815831e+07          NaN

# %% [markdown]
# # write down all the numeric variables and make them numeric?
# 1. size
# 2. install
# 3. price

# %%
# to do that lets have  a look on th unique values
df['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
#        '5.1M', '61M', '66M', '79k', '8.4M', '118k', '44M', '695k', '1.6M',
#        '6.2M', '18k', '53M', '1.4M', '3.0M', '5.8M', '3.8M', '9.6M',
#        '45M', '63M', '49M', '77M', '4.4M', '4.8M', '70M', '6.9M', '9.3M',
#        '10.0M', '8.1M', '36M', '84M', '97M', '2.0M', '1.9M', '1.8M',
#        '5.3M', '47M', '556k', '526k', '76M', '7.6M', '59M', '9.7M', '78M',
#        '72M', '43M', '7.7M', '6.3M', '334k', '34M', '93M', '65M', '79M',
#        '100M', '58M', '50M', '68M', '64M', '67M', '60M', '94M', '232k',
#        '99M', '624k', '95M', '8.5k', '41k', '292k', '11k', '80M', '1.7M',
#        '74M', '62M', '69M', '75M', '98M', '85M', '82M', '96M', '87M',
#        '71M', '86M', '91M', '81M', '92M', '83M', '88M', '704k', '862k',
#        '899k', '378k', '266k', '375k', '1.3M', '975k', '980k', '4.1M',
#        '89M', '696k', '544k', '525k', '920k', '779k', '853k', '720k',
#        '713k', '772k', '318k', '58k', '241k', '196k', '857k', '51k',
#        '953k', '865k', '251k', '930k', '540k', '313k', '746k', '203k',
#        '26k', '314k', '239k', '371k', '220k', '730k', '756k', '91k',
#        '293k', '17k', '74k', '14k', '317k', '78k', '924k', '902k', '818k',
#        '81k', '939k', '169k', '45k', '475k', '965k', '90M', '545k', '61k',
#        '283k', '655k', '714k', '93k', '872k', '121k', '322k', '1.0M',
#        '976k', '172k', '238k', '549k', '206k', '954k', '444k', '717k',
#        '210k', '609k', '308k', '705k', '306k', '904k', '473k', '175k',
#        '350k', '383k', '454k', '421k', '70k', '812k', '442k', '842k',
#        '417k', '412k', '459k', '478k', '335k', '782k', '721k', '430k',
#        '429k', '192k', '200k', '460k', '728k', '496k', '816k', '414k',
#        '506k', '887k', '613k', '243k', '569k', '778k', '683k', '592k',
#        '319k', '186k', '840k', '647k', '191k', '373k', '437k', '598k',
#        '716k', '585k', '982k', '222k', '219k', '55k', '948k', '323k',
#        '691k', '511k', '951k', '963k', '25k', '554k', '351k', '27k',
#        '82k', '208k', '913k', '514k', '551k', '29k', '103k', '898k',
#        '743k', '116k', '153k', '209k', '353k', '499k', '173k', '597k',
#        '809k', '122k', '411k', '400k', '801k', '787k', '237k', '50k',
#        '643k', '986k', '97k', '516k', '837k', '780k', '961k', '269k',
#        '20k', '498k', '600k', '749k', '642k', '881k', '72k', '656k',
#        '601k', '221k', '228k', '108k', '940k', '176k', '33k', '663k',
#        '34k', '942k', '259k', '164k', '458k', '245k', '629k', '28k',
#        '288k', '775k', '785k', '636k', '916k', '994k', '309k', '485k',
#        '914k', '903k', '608k', '500k', '54k', '562k', '847k', '957k',
#        '688k', '811k', '270k', '48k', '329k', '523k', '921k', '874k',
#        '981k', '784k', '280k', '24k', '518k', '754k', '892k', '154k',
#        '860k', '364k', '387k', '626k', '161k', '879k', '39k', '970k',
#        '170k', '141k', '160k', '144k', '143k', '190k', '376k', '193k',
#        '246k', '73k', '658k', '992k', '253k', '420k', '404k', '470k',
#        '226k', '240k', '89k', '234k', '257k', '861k', '467k', '157k',
#        '44k', '676k', '67k', '552k', '885k', '1020k', '582k', '619k'],
#       dtype=object)

# %%
df['Size'].value_counts()
# Out:
# Size
# Varies with device    1695
# 11M                    198
# 12M                    196
# 14M                    194
# 13M                    191
#                       ...
# 253k                     1
# 992k                     1
# 658k                     1
# 73k                      1
# 246k                     1
# Name: count, Length: 461, dtype: int64

# %% [markdown]
# # Check that how many MBs are there in one KB? and how to calculate ?
# 1. convert KBs into M
# 2. then remove M from all numbers
# 3. handle `Varies with device`

# %%
df['Size'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # install column

# %%
df['Installs'].value_counts()
# Out:
# Installs
# 1,000,000+        1579
# 10,000,000+       1252
# 100,000+          1169
# 10,000+           1054
# 1,000+             908
# 5,000,000+         752
# 100+               719
# 500,000+           539
# 50,000+            479
# 5,000+             477
# 100,000,000+       409
# 10+                386
# 500+               330
# 50,000,000+        289
# 50+                205
# 5+                  82
# 500,000,000+        72
# 1+                  67
# 1,000,000,000+      58
# 0+                  14
# 0                    1
# Name: count, dtype: int64

# %% [markdown]
# #  do it as numeric column or group that into different group following bining method

# %% [markdown]
# # How to handle the price

# %%
df['Price'].value_counts()
# Out:
# Price
# 0          10041
# $0.99        148
# $2.99        129
# $1.99         73
# $4.99         72
#            ...
# $3.61          1
# $394.99        1
# $1.26          1
# $1.20          1
# $1.04          1
# Name: count, Length: 92, dtype: int64

# %%
df['Price'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Remove $ sign from all columns using pandas

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver  Unnamed: 13
# 0  4.0.3 and up          NaN
# 1  4.0.3 and up          NaN
# 2  4.0.3 and up          NaN
# 3    4.2 and up          NaN
# 4    4.4 and up          NaN

# %%
df['Type'].value_counts()
# Out:
# Type
# Free    10040
# Paid      800
# Name: count, dtype: int64
